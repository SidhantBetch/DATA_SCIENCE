# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("Churn_Modelling.csv")

# %%
dataset.head(2)
# Out:
#    CreditScore  Age  Tenure   Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2      0.00              1          1
# 1          608   41       1  83807.86              1          0
#
#    IsActiveMember  EstimatedSalary  Exited
# 0               1        101348.88       1
# 1               1        112542.58       0

# %% [markdown]
# Insure data has not null value

# %%
dataset.isnull().sum()
# Out:
# CreditScore        0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
input_data = dataset.iloc[:,:-1]
output_data = dataset["Exited"]

# %% [markdown]
# Scaling

# %%
ss = StandardScaler()
input_data = pd.DataFrame(ss.fit_transform(input_data),columns=input_data.columns)

# %% [markdown]
# Train Test Split data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(input_data,output_data,train_size=0.25,random_state=10)

# %%
x_train.shape
# Out:
# (2500, 8)

# %% [markdown]
# ***MultiLayer Percepton***

# %%
import tensorflow

# %% [markdown]
# # *Dropout Layer*

# %%
from keras.layers import Dense, Dropout
from keras.regularizers import L2
from keras.callbacks import EarlyStopping

from keras.models import Sequential

# %%
ann = Sequential()

# %%
ann.add(Dense(6,input_dim = 8,activation="relu",kernel_regularizer = L2(l2=0.01)))
ann.add(Dropout(0.5))
ann.add(Dense(4,activation="relu"))
ann.add(Dropout(0.5))
ann.add(Dense(2,activation="relu"))
ann.add(Dropout(0.5))
ann.add(Dense(1,activation="sigmoid"))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
ann.compile(optimizer = "adam", loss = "binary_crossentropy",metrics=['accuracy'])

# %%
ann.fit(x_train,y_train, batch_size=100, epochs = 50,validation_data=(x_test,y_test),callbacks=EarlyStopping())
# Out:
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.7328 - loss: 0.8543 - val_accuracy: 0.6173 - val_loss: 0.7747
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7284 - loss: 0.8302 - val_accuracy: 0.6659 - val_loss: 0.7362
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7264 - loss: 0.8066 - val_accuracy: 0.7055 - val_loss: 0.7057
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7444 - loss: 0.7621 - val_accuracy: 0.7363 - val_loss: 0.6850
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7504 - loss: 0.7221 - val_accuracy: 0.7583 - val_loss: 0.6678
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7584 - loss: 0.6962 - val_accuracy: 0.7795 - val_loss: 0.6530
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7616 - loss: 0.6768 - val_accuracy: 0.7889 - val_loss: 0.6398
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7768 - loss: 0.6628 - val_accuracy: 0.7935 - val_loss: 0.6290
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7792 - loss: 0.6505 - val_accuracy: 0.7943 - val_loss: 0.6191
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7840 - loss: 0.6381 - val_accuracy: 0.7943 - val_loss: 0.6099
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7904 - loss: 0.6315 - val_accuracy: 0.7943 - val_loss: 0.6010
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7880 - loss: 0.6207 - val_accuracy: 0.7943 - val_loss: 0.5931
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7924 - loss: 0.6191 - val_accuracy: 0.7943 - val_loss: 0.5864
# Epoch 14/50
#  1/25 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8000 - loss: 0.5839

# %% [markdown]
# ***Handling overfitting using Batch Normalization***

# %%
train_accuracy = ann.history.history["accuracy"]
test_accuracy = ann.history.history["val_accuracy"]

# %%
plt.plot([i for i in range(1,51)],train_accuracy)
plt.plot([i for i in range(1,51)],test_accuracy)
plt.show()

# %% [markdown]
# # Identity overfitting

# %%
from sklearn.metrics import accuracy_score

# %%
prd = ann.predict(x_test)
prd_data = []
for i in prd:
  if i[0] > 0.5 :
    prd_data.append(1)
  else:
    prd_data.append(0)

# %%
accuracy_score(y_test,prd_data)*100

# %%
prd1 = ann.predict(x_train)
prd_data1 = []
for i in prd1:
  if i[0] > 0.5 :
    prd_data1.append(1)
  else:
    prd_data1.append(0)

# %%
accuracy_score(y_train,prd_data1)*100

# %% [markdown]
# Hance, our model is overfitted because test score is 79 and train score is 80
