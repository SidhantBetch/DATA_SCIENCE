# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("Titanic-Dataset.csv")

# %%
dataset.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
dataset["Age"].fillna(dataset["Age"].mean(),inplace=True)
# Out:
# /tmp/ipykernel_830/706645804.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Age"].fillna(dataset["Age"].mean(),inplace=True)

# %%
md = np.median(dataset["Age"])
md
# Out:
# np.float64(29.69911764705882)

# %%
#OR
dataset["Age"].median()
# Out:
# 29.69911764705882

# %%
mn = dataset["Age"].mean()
mn
# Out:
# np.float64(29.69911764705882)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(x="Age",data=dataset, bins=[i for i in range(0,81,10)])
plt.plot([mn for i in range(0,390)],[i for i in range(0,390)],c="red")
plt.plot([md for i in range(0,300)],[i for i in range(0,300)],c="yellow")
plt.show()
