# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("iris.csv")

dataset.drop(columns=["Unnamed: 0","Species"],inplace=True)

# %%
dataset.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2

# %%
plt.figure(figsize=(3,3))
sns.pairplot(data=dataset)
plt.show()

# %% [markdown]
# # *CLUSTRING*

# %% [markdown]
# ***K-MEAN CLUSTRING***

# %%
from sklearn.cluster import KMeans

# %%
wcss = []

for i in range(2,21):
  km = KMeans(n_clusters=i, init='k-means++')
  km.fit(dataset)
  wcss.append(km.inertia_)

# %%
plt.figure(figsize=(10,5))
plt.plot([i for i in range(2,21)],wcss,marker = "o")
plt.xlabel("no of Cluster")
plt.xticks([i for i in range(2,21)])
plt.ylabel("wcss")
plt.grid(axis='x')
plt.show()

# %%
kmn = KMeans(n_clusters=3)
dataset["Predict"] = kmn.fit_predict(dataset)

# %%
dataset.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Predict
# 0           5.1          3.5           1.4          0.2        1
# 1           4.9          3.0           1.4          0.2        1
# 2           4.7          3.2           1.3          0.2        1
# 3           4.6          3.1           1.5          0.2        1
# 4           5.0          3.6           1.4          0.2        1

# %%
sns.pairplot(data=dataset,hue="Predict")
plt.show()

# %% [markdown]
# ***campare with original species to predict species***

# %%
org_dataset = pd.read_csv("iris.csv")

org_dataset.drop(columns=["Unnamed: 0"],inplace=True)

# %%
org_dataset.head(2)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
sns.pairplot(data=org_dataset,hue="Species")
plt.show()
