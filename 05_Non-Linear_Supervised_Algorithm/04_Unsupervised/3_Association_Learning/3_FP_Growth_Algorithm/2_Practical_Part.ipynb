# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option("display.max_rows",200)# used to show more data in output box

# %%
dataset = pd.read_csv("groceries - groceries.csv")

# dataset.drop(columns=["Unnamed: 0","Species"],inplace=True)

# %%
dataset.head(2)
# Out:
#    Item(s)          Item 1               Item 2     Item 3       Item 4  \
# 0        4    citrus fruit  semi-finished bread  margarine  ready soups
# 1        3  tropical fruit               yogurt     coffee          NaN
#
#   Item 5 Item 6 Item 7 Item 8 Item 9 Item 10 Item 11
# 0    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1    NaN    NaN    NaN    NaN    NaN     NaN     NaN

# %%
dataset.columns
# Out:
# Index(['Item(s)', 'Item 1', 'Item 2', 'Item 3', 'Item 4', 'Item 5', 'Item 6',
#        'Item 7', 'Item 8', 'Item 9', 'Item 10', 'Item 11'],
#       dtype='object')

# %% [markdown]
# remove nan value

# %%
market = []
for i in range(0,dataset.shape[0]):
  cus = []
  for j in dataset.columns:
    if type(dataset[j][i]) == str:
      cus.append(dataset[j][i])
  market.append(cus)

# %% [markdown]
# ***find most salling product***

# %% [markdown]
# convert data into single list for finding most salling product

# %%
import numpy as np

l =[]
for i in market:
  for j in i:
    l.append(j)

# %% [markdown]
# conut the data frequency

# %%
import collections

# %%
p = collections.Counter(l)

# %% [markdown]
# create data Frame for observation

# %%
d = {"Item Nmae":p.keys(),"Values":p.values()}

# %%
# pd.DataFrame(d).sort_values(by=["Values"],ascending = False)

# %% [markdown]
# # ***Association Learning***

# %% [markdown]
# data encoding

# %%
from mlxtend.preprocessing.transactionencoder import TransactionEncoder

# %%
tr = TransactionEncoder()
tr.fit(market)
# Out:
# TransactionEncoder()

# %%
df = pd.DataFrame(tr.transform(market),columns=tr.columns_)

# %% [markdown]
# FP Growth Algorithm

# %%
from mlxtend.frequent_patterns import fpgrowth
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
fpgrowth(df,min_support=0.07,use_colnames=True,max_len=3)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
fpgrowth(df,min_support=0.07,use_colnames=True,max_len=3).sort_values(by="support")
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...
